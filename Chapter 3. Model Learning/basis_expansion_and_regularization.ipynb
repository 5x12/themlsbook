# %% [markdown]
# # BASIS EXPANSION
#
# This Jupyter Notebook is a supplement for **Chapter 5. Regression Models** of the [Machine Learning For Everyone](ml4everyonebook.com) book.

# %% [markdown]
# # 1. Data & Basic Libraries
#
# Let's import basic libraries and the data that we use in the book.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Defined data
X_train = [30, 46, 60, 65, 77, 95]
y_train = [31, 30, 80, 49, 70, 118]

X_test = [17, 40, 55, 57, 70, 85]
y_test = [19, 50, 60, 32, 90, 110]

# %% [markdown]
# Let's visualize the data on the graph.

# %%
plt.figure(figsize=(6, 4))
plt.scatter(X_train, y_train, color='blue', label='Training set')
plt.scatter(X_test, y_test, color='red', label='Test set')
plt.title('The data')
plt.legend(loc='best')

# %% [markdown]
# # 2. Building Three Polynomial Models

# %% [markdown]
# ## 2.1. First-degree polynomial

# %%
# build a model
degrees = 1
p = np.poly1d(np.polyfit(X_train, y_train, degrees))
t = np.linspace(0, 100, 100)

# visualize
plt.plot(X_train, y_train, 'o', t, p(t), '-')
plt.scatter(X_train, y_train, color='blue', label='Training set')
plt.scatter(X_test, y_test, color='red', label='Test set')
plt.legend(loc='best')
plt.xlim((0,100))
plt.ylim((0,130))
plt.show()

# %% [markdown]
# ## 2.1. Second-degree polynomial

# %%
# build a model
degrees = 2
p = np.poly1d(np.polyfit(X_train, y_train, degrees))
t = np.linspace(0, 100, 100)

# visualize
plt.plot(X_train, y_train, 'o', t, p(t), '-')
plt.scatter(X_train, y_train, color='blue', label='Training set')
plt.scatter(X_test, y_test, color='red', label='Test set')
plt.legend(loc='best')
plt.xlim((0,100))
plt.ylim((0,130))
plt.show()

# %% [markdown]
# Let's see the estimated coefficients of the model

# %%
list(p.coef)
# Out:
# [0.01442599953834013, -0.497341624767477, 31.898294657797543]

# %% [markdown]
# Let's see their absolute sum:

# %%
sum(abs(p.coef))
# Out:
# 32.41006228210336

# %%
#or 
31.9 + 0.5 + 0.014
# Out:
# 32.414

# %% [markdown]
# We can use the built model p(t) if we want to predict the price of any apartment, given its area. Let's predict the price of a 30-meter-squared apartment.

# %%
p(30) #in 10,000 -> 299,614
# Out:
# 29.96144549927935

# %%
#alternatively:
def f(x):
    return np.array([(31.9 - 0.5 * i + 0.014 * i**2) for i in x])

# %% [markdown]
# ## Let's calculate SSR_training and SSR_test:

# %%
predict_train = p(X_train)
SSR_train = sum((predict_train-y_train)**2)

predict_test = p(X_test)
SSR_test = sum((predict_test-y_test)**2)

print('SSR_train = {} \n \n SSR_test = {}'.format(SSR_train, SSR_test))
# Out:
# SSR_train = 994.7785614408566
#
#  SSR_test = 1530.3762231241055

# %%
predict_train = f(X_train)
SSR_train = sum((predict_train-y_train)**2)

predict_test = f(X_test)
SSR_test = sum((predict_test-y_test)**2)

print('SSR_train = {} \n \n SSR_test = {}'.format(SSR_train, SSR_test))
# Out:
# SSR_train = 1027.0004120000003
#
#  SSR_test = 1757.0769119999998

# %% [markdown]
# ## 2.2. Fourth-degree polynomial

# %%
# build a model
degrees = 4
p = np.poly1d(np.polyfit(X_train, y_train, degrees))
t = np.linspace(0, 100, 100)

# visualize
plt.plot(X_train, y_train, 'o', t, p(t), '-')
plt.scatter(X_train, y_train, color='blue', label='Training set')
plt.scatter(X_test, y_test, color='red', label='Test set')
plt.legend(loc='best')
plt.ylim((0,120))
plt.show()

# %% [markdown]
# Let's see the estimated coefficients of the model

# %%
list(p.coef)
# Out:
# [8.489668977513436e-05,
#  -0.020758975169599018,
#  1.8214724130893771,
#  -66.46265046423612,
#  876.8597601248072]

# %% [markdown]
# Let's see their absolute sum:

# %%
sum(abs(p.coef))
# Out:
# 945.1647268739921

# %%
876.9+66.46+1.821+0.02076+0.0000849
# Out:
# 945.2018449000001

# %%
#alternatively:
def f(x):
    return np.array([(876.9-66.46*i+1.821*i**2-0.02076*i**3+0.0000849*i**4) for i in x])

# %%
f([30])
# Out:
# array([30.249])

# %% [markdown]
# We can use the built model p(t) if we want to predict the price of any apartment, given its area. Let's predict the price of a 12-meter-squared apartment.

# %%
p(30)
# Out:
# 30.5794071168483

# %% [markdown]
# Let's calculate SSR_training and SSR_test:

# %%
predict_train = p(X_train)
SSR_train = sum((predict_train-y_train)**2)

predict_test = p(X_test)
SSR_test = sum((predict_test-y_test)**2)

print('SSR_train = {} \n \n SSR_test = {}'.format(SSR_train, SSR_test))
# Out:
# SSR_train = 651.4179373306126
#
#  SSR_test = 29010.616059842923

# %%
predict_train
# Out:
# array([ 30.57940712,  33.33905077,  62.72388224,  67.03384222,
#         65.96521691, 118.35860073])

# %%
f(X_train)
# Out:
# array([ 30.249    ,  32.4166544,  61.044    ,  65.0280625,  63.0571009,
#        113.7780625])

# %%
predict_train = f(X_train)
SSR_train = sum((predict_train-y_train)**2)

predict_test = f(X_test)
SSR_test = sum((predict_test-y_test)**2)

print('SSR_train = {} \n \n SSR_test = {}'.format(SSR_train, SSR_test))
# Out:
# SSR_train = 688.6615471596378
#
#  SSR_test = 29379.046097639017

# %% [markdown]
# ## 2.3. Sixth-degree polynomial

# %%
# build a model
degrees = 6
p = np.poly1d(np.polyfit(X_train, y_train, degrees))
t = np.linspace(0, 100, 100)

# visualize
plt.plot(X_train, y_train, 'o', t, p(t), '-')
plt.scatter(X_train, y_train, color='blue', label='Training set')
plt.scatter(X_test, y_test, color='red', label='Test set')
plt.legend(loc='best')
plt.ylim((0,120))
plt.show()
# Out:
# /Users/andrewwolf/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3343: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# Let's see the estimated coefficients of the model

# %%
list(p.coef)
# Out:
# [-1.9967886455401742e-07,
#  4.4303130723314564e-05,
#  -0.0018657593425881595,
#  -0.249489794020564,
#  27.986144920903786,
#  -996.4647121869306,
#  12053.900258529504]

# %% [markdown]
# Let's see their absolute sum:

# %%
#alternatively:
def f(x):
    return np.array([(-1.996789e-07*i**6
                      +4.430313e-05*i**5
                      -0.001865759*i**4
                      -0.24949*i**3
                      +27.9861*i**2
                      -996.46*i
                      +12053.9) for i in x])

# #alternatively:
# def f(x):
#     return np.array([(876.9-66.46*i+1.821*i**2-0.02076*i**3+0.0000849*i**4) for i in x])

# %%
1.996789e-07+ 4.430313e-05 + 0.001865759 + 0.24949 + 27.9861 + 996.46 + 12053.9
# Out:
# 13078.597500261809

# %%
sum(abs(p.coef))
# Out:
# 13078.60251569351

# %% [markdown]
# We can use the built model p(t) if we want to predict the price of any apartment, given its area. Let's predict the price of a 12-meter-squared apartment.

# %%
p(12)
# Out:
# 3666.9496298304857

# %% [markdown]
# Let's calculate SSR_training and SSR_test:

# %%
predict_train = p(X_train)
SSR_train = sum((predict_train-y_train)**2)

predict_test = p(X_test)
SSR_test = sum((predict_test-y_test)**2)

print('SSR_train = {} \n \n SSR_test = {}'.format(SSR_train, SSR_test))
# Out:
# SSR_train = 2.619515563832928e-20
#
#  SSR_test = 3486393.9095956977

# %%
predict_train = f(X_train)
SSR_train = sum((predict_train-y_train)**2)

predict_test = f(X_test)
SSR_test = sum((predict_test-y_test)**2)

print('SSR_train = {} \n \n SSR_test = {}'.format(SSR_train, SSR_test))
# Out:
# SSR_train = 0.048795124161104236
#
#  SSR_test = 3486619.64011765

# %% [markdown]
# # Regularization

# %%
# Import function to automatically create polynomial features! 
from sklearn.preprocessing import PolynomialFeatures
# Import Linear Regression and a regularized regression function
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.linear_model import LassoCV
# Finally, import function to make a machine learning pipeline
from sklearn.pipeline import make_pipeline

from sklearn.linear_model import Ridge

# %% [markdown]
# Fixing 6-th degree polynomial

# %% [markdown]
# # New - Lasso

# %%
import pandas as pd
from sklearn.linear_model import Ridge, LinearRegression
from sklearn.preprocessing import PolynomialFeatures, scale

d=6

# scale the X data to prevent numerical errors.
X_train = np.array(X_train).reshape(-1, 1)
X_test = np.array(X_test).reshape(-1, 1)

polyX = PolynomialFeatures(degree=d).fit_transform(X_train)

model1 = LinearRegression().fit(polyX, y_train)
model2 = Ridge(alpha=0).fit(polyX, y_train)

print("OLS Coefs: " + str(model1.coef_[0]))
print("Ridge Coefs: " + str(model2.coef_[0]))
# Out:
# OLS Coefs: -7.126951767725101e-05
# Ridge Coefs: 0.0
# /Users/andrewwolf/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_ridge.py:190: UserWarning: Singular matrix in solving dual problem. Using least-squares solution instead.
#   warnings.warn("Singular matrix in solving dual problem. Using "

# %%
t_ = np.array(np.linspace(0, 120, 120)).reshape(-1, 1)
t = PolynomialFeatures(degree=d).fit_transform(t_)


# visualize
plt.plot(X_train, y_train, 'o', t, model2.predict(t), '-')
# plt.scatter(X_train, y_train, color='blue', label='Training set')
# plt.scatter(X_test, y_test, color='red', label='Test set')
plt.legend(loc='best')
plt.ylim((0,120))
plt.xlim((0,120))
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Lasso

# %%
# # Defined data
# X_train = [30, 46, 60, 65, 77, 95]
# y_train = [31, 30, 80, 49, 70, 118]

# X_test = [17, 40, 55, 57, 70, 85]
# y_test = [19, 50, 60, 32, 90, 110]

# %%
X_train = np.array(X_train).reshape(-1, 1)
X_test = np.array(X_test).reshape(-1, 1)

# %%
# lasso_eps = 0.0001
# lasso_nalpha=0.1
# lasso_iter=5000


degree = 4
model = make_pipeline(PolynomialFeatures(degree), Lasso(alpha=1))
model.fit(X_train,y_train)
test_pred = np.array(model.predict(X_test))
RMSE=np.sqrt(np.sum(np.square(test_pred-y_test)))
test_score = model.score(X_test,y_test)
# Out:
# /Users/andrewwolf/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 486.0341144175652, tolerance: 0.5672
#   model = cd_fast.enet_coordinate_descent(

# %%
t = np.array(np.linspace(0, 120, 120)).reshape(-1, 1)


# visualize
plt.plot(X_train, y_train, 'o', t, model.predict(t), '-')
plt.scatter(X_train, y_train, color='blue', label='Training set')
plt.scatter(X_test, y_test, color='red', label='Test set')
plt.legend(loc='best')
plt.ylim((0,140))
plt.show()

# %% [markdown]
# # Ridge

# %%
# ridge_eps = 0.0001
ridge_nalpha=1
# ridge_iter=5000



degree = 4
model = make_pipeline(PolynomialFeatures(degree, interaction_only=False), Ridge(alpha=ridge_nalpha, normalize=True))
model.fit(X_train,y_train)
test_pred = np.array(model.predict(X_test))
RMSE=np.sqrt(np.sum(np.square(test_pred-y_test)))
test_score = model.score(X_test,y_test)

# %%
t = np.array(np.linspace(0, 100, 100)).reshape(-1, 1)


# visualize
plt.plot(X_train, y_train, 'o', t, model.predict(t), '-')
plt.scatter(X_train, y_train, color='blue', label='Training set')
plt.scatter(X_test, y_test, color='red', label='Test set')
plt.legend(loc='best')
plt.ylim((0,120))
plt.show()
